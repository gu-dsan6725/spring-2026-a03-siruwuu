# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve()

if not (PROJECT_ROOT / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

sys.path.append(str(PROJECT_ROOT))

print("Project root:", PROJECT_ROOT)
# Out:
# Project root: /home/ubuntu/spring-2026-a03-siruwuu

# %%
from src.part2_q1 import answer_q1
from src.part2_q2 import answer_q2
from src.part2_q3 import answer_q3
from src.part2_q4 import answer_q4
from src.part2_q5 import answer_q5
from src.part2_q6 import answer_q6

# %%
print(answer_q1("../data", None))
print(answer_q2("../data", None))
print(answer_q3("../data", None))
print(answer_q4("../data", None))
print(answer_q5("../data", None))
print(answer_q6("../data", None))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(answer_q1("data", None))
#       2 print(answer_q2("data", None))
#       3 print(answer_q3("data", None))
#
# File ~/spring-2026-a03-siruwuu/src/part2_q1.py:17, in answer_q1(data_dir, out_file)
#      13 def answer_q1(data_dir: str = "data", out_file: str | None = DEFAULT_OUT_FILE) -> str:
#      14     """
#      15     Q1: What was the total revenue for Electronics category in December 2024?
#      16     """
# ---> 17     df, csv_path = load_sales_df(data_dir)
#      19     if "category" not in df.columns or "total_revenue" not in df.columns:
#      20         raise ValueError("CSV missing required columns: category, total_revenue")
#
# File ~/spring-2026-a03-siruwuu/src/part2_common.py:31, in load_sales_df(data_dir)
#      30 def load_sales_df(data_dir: str) -> Tuple[pd.DataFrame, Path]:
# ...
