# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve()

if not (PROJECT_ROOT / "src").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

sys.path.append(str(PROJECT_ROOT))

print("Project root:", PROJECT_ROOT)
# Out:
# Project root: /home/ubuntu/spring-2026-a03-siruwuu

# %%
from pathlib import Path

from src.part2_q1 import answer_q1
from src.part2_q2 import answer_q2
from src.part2_q3 import answer_q3
from src.part2_q4 import answer_q4
from src.part2_q5 import answer_q5
from src.part2_q6 import answer_q6

data_dir = "../data"  

parts = []
parts.append("Part 2 Results\n")

parts.append(answer_q1(data_dir, None))
parts.append(answer_q2(data_dir, None))
parts.append(answer_q3(data_dir, None))
parts.append(answer_q4(data_dir, None))
parts.append(answer_q5(data_dir, None))
parts.append(answer_q6(data_dir, None))

full_text = "\n\n".join(parts).strip() + "\n"
Path("part2_results.txt").write_text(full_text, encoding="utf-8")

print("Wrote part2_results.txt")
print(full_text[:800])
# Out:
# Wrote part2_results.txt
# Part 2 Results
#
#
# Part 2 Results
#
# Q1: "What was the total revenue for Electronics category in December 2024?"
#
# Answer:
#
# Total revenue for Electronics in Dec 2024 is 142864.31.
#
# Files referenced:
# - ../data/structured/daily_sales.csv
#
#
# Part 2 Results
#
# Q2: "Which region had the highest sales volume?"
#
# Answer:
#
# The region with the highest total units sold is "Central" with 6779 units.
#
# Files referenced:
# - ../data/structured/daily_sales.csv
#
#
# Part 2 Results
#
# Q3: "What are the key features of the Wireless Bluetooth Headphones?"
#
# Answer:
#
# Based on ELEC001_product_page.txt, the key features mentioned include (excerpt):
#
# ...
# WIRELESS BLUETOOTH HEADPHONES - PRODUCT PAGE
# ...
#
# Product: Wireless Bluetooth Headphones
# Brand: SoundMa

# %%
from pathlib import Path
from src.part2_answer import answer_part2

data_dir = "../data"

queries = [
    "What was the total revenue for Electronics category in December 2024?",
    "Which region had the highest sales volume?",
    "What are the key features of the Wireless Bluetooth Headphones?",
    "What do customers say about the Air Fryer's ease of cleaning?",
    "Which product has the best customer reviews and how well is it selling?",
    "I want a product for fitness that is highly rated and sells well in the West region. What do you recommend?",
]

parts = ["Part 2 Results\n"]
for i, q in enumerate(queries, 1):
    parts.append(f"Q{i}\n" + answer_part2(q, data_dir=data_dir) + "\n")

full_text = "\n".join(parts).strip() + "\n"
Path("part2_results.txt").write_text(full_text, encoding="utf-8")

print("Wrote part2_results.txt")
print(full_text[:800])
# Out:
# Wrote part2_results.txt
# Part 2 Results
#
# Q1
# Query: "What was the total revenue for Electronics category in December 2024?"
# Router decision: csv
#
# Retrieved context:
# CSV: Electronics total_revenue in Dec 2024 = 142864.31
#
# Files referenced:
# - ../data/structured/daily_sales.csv
#
# Q2
# Query: "Which region had the highest sales volume?"
# Router decision: csv
#
# Retrieved context:
# CSV: top region by units_sold = Central (6779)
#
# Files referenced:
# - ../data/structured/daily_sales.csv
#
# Q3
# Query: "What are the key features of the Wireless Bluetooth Headphones?"
# Router decision: text
#
# Retrieved context:
# TEXT from ELEC001_product_page.txt:
# ...
# WIRELESS BLUETOOTH HEADPHONES - PRODUCT PAGE
# ...
#
# Product: Wireless Bluetooth Headphones
# Brand: SoundMax Pro
# Price: $
